# %%
act <- read.csv("activities.csv")

# %%
athletes <- read.csv("athletes.csv")
# Out:
# Warning message:
# In scan(file = file, what = what, sep = sep, quote = quote, dec = dec, : embedded nul(s) found in input

# %%
summary(act);
# Out:
#                                  X_id
#  ObjectID(5476536bdb46657063ed82da):      1
#  ObjectID(54765371db46657063ed82db):      1
#  ObjectID(5476538bdb46657063ed82dc):      1
#  ObjectID(5476538ddb46657063ed82dd):      1
#  ObjectID(54765393db46657063ed82de):      1
#  ObjectID(54765394db46657063ed82df):      1
#  (Other)                           :1324089
#                                                url
#  https://www.strava.com/api/v3/activities/1000000:      1
#  https://www.strava.com/api/v3/activities/1000001:      1
#  https://www.strava.com/api/v3/activities/1000002:      1
#  https://www.strava.com/api/v3/activities/1000003:      1
#  https://www.strava.com/api/v3/activities/1000004:      1
#  https://www.strava.com/api/v3/activities/1000006:      1
#  (Other)                                         :1324089
#                        utc          values.athlete_count values.trainer
#  2014-11-26T22:25:47.184Z:      1   Min.   :  1.000      false:1292220
# ...

# %%
summary(athletes)
# Out:
#                                  X_id
#  ObjectID(5468b6fadb46656d1b917b07):     1
#  ObjectID(5468b6fcdb46656d1b917b08):     1
#  ObjectID(5468b6fedb46656d1b917b09):     1
#  ObjectID(5468b735db46656d30224072):     1
#  ObjectID(5468b737db46656d30224073):     1
#  ObjectID(5468b739db46656d30224074):     1
#  (Other)                           :743239
#                                             url
#  https://www.strava.com/api/v3/athletes/10    :     2
#  https://www.strava.com/api/v3/athletes/12    :     2
#  https://www.strava.com/api/v3/athletes/9     :     2
#  https://www.strava.com/api/v3/athletes/10000 :     1
#  https://www.strava.com/api/v3/athletes/100000:     1
#  https://www.strava.com/api/v3/athletes/100001:     1
#  (Other)                                      :743236
#                        utc
#  2014-11-16T14:38:50.526Z:     1
#  2014-11-16T14:38:52.071Z:     1
#  2014-11-16T14:38:54.541Z:     1
#  2014-11-16T14:39:49.799Z:     1
# ...
